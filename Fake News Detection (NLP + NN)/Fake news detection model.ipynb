# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten
from sklearn.metrics import accuracy_score, precision_score

# Load the dataset
data = pd.read_csv("article_headlines.csv")
headlines = data["Headline"].values
labels = data["Label"].values

# Preprocess the text data (a)
#Tokenization
max_words = 1000
tokenizer = Tokenizer(num_words = max_words)
tokenizer.fit_on_texts(headlines)
sequences = tokenizer.texts_to_sequences(headlines)

#Padding
max_length = 20
padded_sequences = pad_sequences(sequences, maxlen = max_length)
labels = np.array(labels)
x_train, x_test, y_train, y_test = train_test_split(padded_sequences, labels, test_size = 0.2, random_state = 42)

# Build the neural network (b)
model = Sequential()
model.add(Embedding(1000, 16))
model.add(Flatten())
model.add(Dense(16, activation = "relu"))
model.add(Dense(1, activation = "sigmoid"))
model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ["accuracy"])

# Train the model and evaluate (c)
model.fit(x_train, y_train, epochs = 10, batch_size = 32, validation_split = 0.2)
y_pred = (model.predict(x_test) > 0.5).astype(int)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Precision:", precision)
# Out:
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 403ms/step - accuracy: 0.5417 - loss: 0.6893 - val_accuracy: 0.8750 - val_loss: 0.6763
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.6769 - val_accuracy: 0.8750 - val_loss: 0.6666
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.6634 - val_accuracy: 0.8750 - val_loss: 0.6558
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.6505 - val_accuracy: 0.8750 - val_loss: 0.6443
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.6374 - val_accuracy: 0.8750 - val_loss: 0.6313
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.6223 - val_accuracy: 0.8750 - val_loss: 0.6173
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 1.0000 - loss: 0.6055 - val_accuracy: 0.8750 - val_loss: 0.6018
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 0.5868 - val_accuracy: 0.8750 - val_loss: 0.5847
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.5674 - val_accuracy: 0.8750 - val_loss: 0.5662
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.5477 - val_accuracy: 0.8750 - val_loss: 0.5458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# Accuracy: 1.0
# Precision: 1.0
